# %% [markdown]
# <a href="https://colab.research.google.com/github/tutsilianna/Introduction_to_ML_and_Advanced_ML_Python/blob/main/Introduction/Introduction_%7C_Expercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The [file](https://drive.google.com/file/d/1YrEIn6JNWW0RG0r8nV0P6S55TBXcxSna/view?usp=drive_link) contains the data on the average salary and population in Russia as of January 1, 2019 (according to the Russian Federal State Statistics Service). Imagine that someone has forgotten to mention Vologda Region, Murmansk Region. These regions should not be included in the summary. Please delete the data on these regions from the file and work with a new sample saved in the CSV format.
#
# * Find the sample mean of the salary
# * Find the sample median Me of the salary
# * Find the variance estimate S^2 of the salary
# * Find the standard deviation σ of the salary

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/itmo|AI_cources/salary_and_population.csv', encoding = 'utf-8', delimiter=',')

# %%
data.drop('Unnamed: 4', axis=1, inplace=True)
data.head()
# Out:
#                Region_RU           Region_EN  AVG_Salary  Population
# 0         Алтайский край        Altai Region       25960      218866
# 1       Амурская область         Amur Region       43156      793194
# 2  Архангельская область  Arkhangelsk Region       47526     1144119
# 3   Астраханская область    Astrakhan Region       32166     1014065
# 4   Белгородская область     Belgorod Region       31163     1547418

# %%
data
# Out:
#                 Region_RU                          Region_EN  AVG_Salary  \
# 0          Алтайский край                       Altai Region       25960
# 1        Амурская область                        Amur Region       43156
# 2   Архангельская область                 Arkhangelsk Region       47526
# 3    Астраханская область                   Astrakhan Region       32166
# 4    Белгородская область                    Belgorod Region       31163
# ..                    ...                                ...         ...
# 80   Чеченская Республика               Republic of Chechnya       26108
# 81   Чувашская Республика                   Chuvash Republic       27028
# 82           Чукотский АО                        Chukotka AO       96930
# 83      Ямало-Ненецкий АО  Yamalo-Nenets Autonomous district       86560
# 84    Ярославская область                   Yaroslavl Region       33882
#
#     Population
# 0       218866
# 1       793194
# 2      1144119
# 3      1014065
# ...

# %%
data['Region_RU'].unique()
# Out:
# array(['Алтайский край', 'Амурская область', 'Архангельская область',
#        'Астраханская область', 'Белгородская область', 'Брянская область',
#        'Владимирская область', 'Волгоградская область',
#        'Вологодская область', 'Воронежская область', 'г Москва',
#        'г Санкт-Петербург', 'г Севастополь', 'Еврейская АО',
#        'Забайкальский край', 'Ивановская область', 'Иркутская область',
#        'Кабардино-Балкарская Республика', 'Калининградская область',
#        'Калужская область', 'Камчатский край',
#        'Карачаево-Черкесская Республика', 'Кемеровская область',
#        'Кировская область', 'Костромская область', 'Краснодарский край',
#        'Красноярский край', 'Курганская область', 'Курская область',
#        'Ленинградская область', 'Липецкая область', 'Магаданская обл',
#        'Московская обл', 'Мурманская обл', 'Ненецкий АО',
#        'Нижегородская область', 'Новгородская область',
# ...

# %%
data = data.loc[(data['Region_RU'] != 'Вологодская область') & (data['Region_RU'] != 'Мурманская обл')]

# %%
f"The sample mean of the salary = {round(data['AVG_Salary'].mean(), 2)}"
# Out:
# 'The sample mean of the salary = 38658.04'

# %%
f"The sample median of the salary = {round(data['AVG_Salary'].median(), 2)}"
# Out:
# 'The sample median of the salary = 32473.0'

# %%
f"The variance estimate of the salary = {round(data['AVG_Salary'].var(ddof=0), 2)}"
# Out:
# 'The variance estimate of the salary = 270512026.47'

# %%
f"The standard deviation of the salary = {round(data['AVG_Salary'].std(ddof=0), 2)}"
# Out:
# 'The standard deviation of the salary = 16447.25'
